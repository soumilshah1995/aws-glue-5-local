# %% [markdown]
# ## REST CATALOG

# %%
# %%configure
# {
#   "conf": {
#     "spark.sql.extensions": "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions",
#     "spark.sql.defaultCatalog": "s3tables",
#     "spark.sql.catalog.s3tables": "org.apache.iceberg.spark.SparkCatalog",
#     "spark.sql.catalog.s3tables.type": "rest",
#     "spark.sql.catalog.s3tables.uri": "https://s3tables.us-east-1.amazonaws.com/iceberg",
#     "spark.sql.catalog.s3tables.warehouse": "arn:aws:s3tables:us-east-1:<ACCOUNT>:bucket/soumilshah-demo",
#     "spark.sql.catalog.s3tables.rest.sigv4-enabled": "true",
#     "spark.sql.catalog.s3tables.rest.signing-name": "s3tables",
#     "spark.sql.catalog.s3tables.rest.signing-region": "us-east-1",
#     "spark.sql.catalog.s3tables.io-impl": "org.apache.iceberg.aws.s3.S3FileIO",
#     "spark.sql.catalog.s3tables.rest-metrics-reporting-enabled": "false",
#     "spark.sql.parquet.enableVectorizedReader": "false"
#   }
# }
# Out:
# Current session configs: <tt>{'conf': {'spark.sql.catalog.spark_catalog.type': 'hive', 'spark.sql.extensions': 'org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions', 'spark.sql.defaultCatalog': 's3tables', 'spark.sql.catalog.s3tables': 'org.apache.iceberg.spark.SparkCatalog', 'spark.sql.catalog.s3tables.type': 'rest', 'spark.sql.catalog.s3tables.uri': 'https://s3tables.us-east-1.amazonaws.com/iceberg', 'spark.sql.catalog.s3tables.warehouse': 'arn:aws:s3tables:us-east-1:867098943567:bucket/soumilshah-demo', 'spark.sql.catalog.s3tables.rest.sigv4-enabled': 'true', 'spark.sql.catalog.s3tables.rest.signing-name': 's3tables', 'spark.sql.catalog.s3tables.rest.signing-region': 'us-east-1', 'spark.sql.catalog.s3tables.io-impl': 'org.apache.iceberg.aws.s3.S3FileIO', 'spark.sql.catalog.s3tables.rest-metrics-reporting-enabled': 'false', 'spark.sql.parquet.enableVectorizedReader': 'false'}, 'kind': 'pyspark'}</tt><br>
# No active sessions.

# %%
spark
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>0</td><td>None</td><td>pyspark</td><td>idle</td><td></td><td></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...

# %%
# %%sql
# SHOW CATALOGS
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...
# Output()

# %%
# %%sql
# SHOW DATABASES IN s3tables;
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...
# Output()

# %%
# %%sql
# SHOW TABLES IN demo_namespace;
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...
# Output()

# %%
# %%sql
# SELECT * FROM demo_namespace.customer_orders;
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...
# Output()

# %% [markdown]
# # Iceberg V3

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS s3tables.demo_namespace.t1 (
#   id BIGINT,
#   region STRING
# )
# USING iceberg
# PARTITIONED BY (region)
# TBLPROPERTIES (
#   'format-version' = '2'
# );
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...
# Output()

# %%
# %%sql
# INSERT INTO s3tables.demo_namespace.t1 VALUES (1, 'us-east-1');
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...
# Output()

# %%
# %%sql
# SELECT COUNT(*) FROM s3tables.demo_namespace.t1
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...
# Output()
